# %% [markdown]
# <a href="https://colab.research.google.com/github/Justmin-Lee/ML_Lecture/blob/main/Lab_2_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()

# %%
# X and Y data
x_train = [1, 2, 3]
y_train = [2, 3, 4]

# %%
#Hypothesis Wx+b
W = tf.Variable(tf.random_normal([1]), name='weight')
b = tf.Variable(tf.random_normal([1]), name='bias')

hypothesis = x_train * W + b

# %%
#Cost/loss Function
cost = tf.reduce_mean(tf.square(hypothesis - y_train))

# %%
#Minimize (Gradient_descent)
optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.01)
train = optimizer.minimize(cost)

# %%
#Launch the graph in a session
sess = tf.Session()

#Initializes global variables in the graph
sess.run(tf.global_variables_initializer())

# %%
#Fit in the line
for step in range(2001):
  sess.run(train)
  if step % 20 == 0:
    print(step, sess.run(cost), sess.run(W), sess.run(b))
# Out:
# 0 5.4295135 [1.9942096] [1.1957384]
# 20 0.05451406 [1.1710572] [0.84498715]
# 40 0.005295327 [1.0890871] [0.81974995]
# 60 0.004408418 [1.0778608] [0.82512426]
# 80 0.0040001674 [1.0735313] [0.8330478]
# 100 0.0036329844 [1.0700119] [0.8408658]
# 120 0.003299535 [1.0667155] [0.8483418]
# 140 0.0029966917 [1.0635796] [0.8554689]
# 160 0.0027216347 [1.0605912] [0.8622615]
# 180 0.0024718328 [1.0577438] [0.8687347]
# 200 0.0022449596 [1.0550301] [0.8749037]
# 220 0.0020389073 [1.0524439] [0.88078266]
# 240 0.0018517725 [1.0499792] [0.8863854]
# 260 0.0016818136 [1.0476304] [0.8917248]
# 280 0.0015274421 [1.0453919] [0.89681345]
# 300 0.0013872487 [1.0432587] [0.9016629]
# 320 0.0012599212 [1.0412258] [0.90628433]
# 340 0.001144281 [1.039288] [0.9106886]
# 360 0.001039254 [1.0374417] [0.91488594]
# 380 0.00094386865 [1.0356822] [0.91888595]
# 400 0.0008572375 [1.0340054] [0.922698]
# 420 0.0007785542 [1.0324072] [0.9263309]
# 440 0.00070709665 [1.0308843] [0.9297932]
# ...
